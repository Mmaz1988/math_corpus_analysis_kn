# %%
import spacy

# %%
test_corpus = "Let k, l > 0 be parameters. The parabola y = kx^2 - 2kx + l intersects the line y = 4 at two points A and B. These points are distance 6 apart. What is the sum of the squares of the distances from A and B to the origin? Each of the three-digits numbers 111 to 999 is coloured blue or yellow in such a way that the sum of any two (not necessarily different) yellow numbers is equal to a blue number. What is the maximum possible number of yellow numbers there can be? Let the `sparkle' operation on positive integer n consist of calculating the sum of the digits of n and taking its factorial, e.g. the sparkle of 13 is 4! = 24. A robot starts with a positive integer on a blackboard, then after each second for the rest of eternity, replaces the number on the board with its sparkle. For some `special' numbers, if they're the first number, then eventually every number that appears will be less than 6. How many such special numbers are there with at most 36 digits? What is the minimum value of 5x^2+5y^2-8xy when x and y range over all real numbers such that x-2y + y-2x = 40? There exists a unique increasing geometric sequence of five 2-digit positive integers. What is their sum? For how many positive integers m does the equation [ x-1 -2=m/100] have 4 distinct solutions? Suppose that we roll four 6-sided fair dice with faces numbered 1 to~6. Let a/b be the probability that the highest roll is a 5, where a and b are relatively prime positive integers. Find a + b. The points (x, y) satisfying ((x + y - 10)^2 + ( x - y - 10)^2)((x - 8)^2 + ( y - 8)^2) = 0 enclose a convex polygon. What is the area of this convex polygon? Let ABCD be a unit square. Let P be the point on AB such that AP = 1/{20} and let Q be the point on AD such that AQ = 1/{24}. The lines DP and BQ divide the square into four regions. Find the ratio between the areas of the largest region and the smallest region. A function f: mathbb N to mathbb N satisfies the following two conditions for all positive integers n:f(f(f(n)))=8n-7 and f(2n)=2f(n)+1. Calculate f(100)."

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(test_corpus)

# %%
for number, sent in enumerate(doc.sents):
    print(number, sent)
# Out:
# 0 Let k, l > 0 be parameters.
# 1 The parabola y = kx^2 - 2kx + l intersects the line y
# 2 = 4 at two points
# 3 A and B. These points are distance 6 apart.
# 4 What is the sum of the squares of the distances from A and B to the origin?
# 5 Each of the three-digits numbers 111 to 999 is coloured blue or yellow in such a way that the sum of any two (not necessarily different) yellow numbers is equal to a blue number.
# 6 What is the maximum possible number of yellow numbers there can be?
# 7 Let the `sparkle' operation on positive integer n consist of calculating the sum of the digits of n and taking its factorial, e.g. the sparkle of 13 is 4!
# 8 = 24.
# 9 A robot starts with a positive integer on a blackboard, then after each second for the rest of eternity, replaces the number on the board with its sparkle.
# 10 For some `special' numbers, if they're the first number, then eventually every number that appears will be less than 6.
# 11 How many such special numbers are there with at most 36 digits?
# 12 What is the minimum value of 5x^2+5y^2-8xy when x and y range over all real numbers such that x-2y + y-2x = 40?
# 13 There exists a unique increasing geometric sequence of five 2-digit positive integers.
# 14 What is their sum?
# 15 For how many positive integers m does the equation [ x-1 -2=m/100] have 4 distinct solutions?
# 16 Suppose that we roll four 6-sided fair dice with faces numbered 1 to~6.
# 17 Let a/b be the probability that the highest roll is a 5, where a and b are relatively prime positive integers.
# 18 Find a +
# 19 b.
# 20 The points (x, y) satisfying ((x + y - 10)^2 + ( x - y - 10)^2)((x - 8)^2 + ( y - 8)^2) = 0 enclose a convex polygon.
# 21 What is the area of this convex polygon?
# 22 Let ABCD be a unit square.
# 23 Let P be the point on AB such that AP = 1/{20} and let Q be the point on AD such that AQ = 1/{24}.
# 24 The lines DP and BQ divide the square into four regions.
# 25 Find the ratio between the areas of the largest region and the smallest region.
# 26 A function f: mathbb N to mathbb N satisfies the following two conditions for all positive integers n:f(f(f(n)))=8n-7 and f(2n)=2f(n)+1.
# 27 Calculate f(100).

# %%
#looking at the part of speech tags

for token in doc:
    print(token, token.pos_, token.tag_)
# Out:
# Let VERB VB
# k PROPN NNP
# , PUNCT ,
# l X FW
# > PROPN NNP
# 0 NUM CD
# be NOUN NN
# parameters NOUN NNS
# . PUNCT .
# The DET DT
# parabola NOUN NN
# y PROPN NNP
# = PROPN NNP
# kx^2 PROPN NNP
# - PUNCT HYPH
# 2kx PROPN NNP
# + NUM CD
# l NOUN NN
# intersects VERB VBZ
# the DET DT
# line NOUN NN
# y PROPN NNP
# = PUNCT :
# 4 NUM CD
# at ADP IN
# two NUM CD
# points NOUN NNS
# A NOUN NN
# and CCONJ CC
# B. PROPN NNP
# These DET DT
# points NOUN NNS
# are AUX VBP
# distance NOUN NN
# 6 NUM CD
# apart ADV RB
# . PUNCT .
# What PRON WP
# is AUX VBZ
# the DET DT
# sum NOUN NN
# of ADP IN
# the DET DT
# squares NOUN NNS
# of ADP IN
# the DET DT
# distances NOUN NNS
# from ADP IN
# A PROPN NNP
# and CCONJ CC
# B NOUN NN
# to ADP IN
# the DET DT
# origin NOUN NN
# ? PUNCT .
# Each PRON DT
# of ADP IN
# the DET DT
# three NUM CD
# - PUNCT HYPH
# digits NOUN NN
# numbers NOUN NNS
# 111 NUM CD
# to ADP IN
# 999 NUM CD
# is AUX VBZ
# coloured VERB VBN
# blue ADJ JJ
# or CCONJ CC
# yellow ADJ JJ
# in ADP IN
# such DET PDT
# a DET DT
# way NOUN NN
# that PRON WDT
# the DET DT
# sum NOUN NN
# of ADP IN
# any DET DT
# two NUM CD
# ( PUNCT -LRB-
# not PART RB
# necessarily ADV RB
# different ADJ JJ
# ) PUNCT -RRB-
# yellow ADJ JJ
# numbers NOUN NNS
# is AUX VBZ
# equal ADJ JJ
# to ADP IN
# a DET DT
# blue ADJ JJ
# number NOUN NN
# . PUNCT .
# What PRON WP
# is AUX VBZ
# the DET DT
# maximum ADJ JJ
# possible ADJ JJ
# number NOUN NN
# of ADP IN
# yellow ADJ JJ
# numbers NOUN NNS
# there PRON EX
# can AUX MD
# be AUX VB
# ? PUNCT .
# Let VERB VB
# the DET DT
# ` PUNCT ``
# sparkle NOUN NN
# ' PART POS
# operation NOUN NN
# on ADP IN
# positive ADJ JJ
# integer NOUN NN
# n NOUN NN
# consist VERB VB
# of ADP IN
# calculating VERB VBG
# the DET DT
# sum NOUN NN
# of ADP IN
# the DET DT
# digits NOUN NNS
# of ADP IN
# n PROPN NNP
# and CCONJ CC
# taking VERB VBG
# its PRON PRP$
# factorial NOUN NN
# , PUNCT ,
# e.g. ADV RB
# the DET DT
# sparkle NOUN NN
# of ADP IN
# 13 NUM CD
# is AUX VBZ
# 4 NUM CD
# ! PUNCT .
# = NOUN NN
# 24 NUM CD
# . PUNCT .
# A DET DT
# robot NOUN NN
# starts VERB VBZ
# with ADP IN
# a DET DT
# positive ADJ JJ
# integer NOUN NN
# on ADP IN
# a DET DT
# blackboard NOUN NN
# , PUNCT ,
# then ADV RB
# after ADP IN
# each DET DT
# second ADJ JJ
# for ADP IN
# the DET DT
# rest NOUN NN
# of ADP IN
# eternity NOUN NN
# , PUNCT ,
# replaces VERB VBZ
# the DET DT
# number NOUN NN
# on ADP IN
# the DET DT
# board NOUN NN
# with ADP IN
# its PRON PRP$
# sparkle NOUN NN
# . PUNCT .
# For ADP IN
# some DET DT
# ` PUNCT ``
# special ADJ JJ
# ' PUNCT ''
# numbers NOUN NNS
# , PUNCT ,
# if SCONJ IN
# they PRON PRP
# 're AUX VBP
# the DET DT
# first ADJ JJ
# number NOUN NN
# , PUNCT ,
# then ADV RB
# eventually ADV RB
# every DET DT
# number NOUN NN
# that PRON WDT
# appears VERB VBZ
# will AUX MD
# be AUX VB
# less ADJ JJR
# than ADP IN
# 6 NUM CD
# . PUNCT .
# How SCONJ WRB
# many ADJ JJ
# such ADJ JJ
# special ADJ JJ
# numbers NOUN NNS
# are AUX VBP
# there ADV RB
# with ADP IN
# at ADP IN
# most ADV RBS
# 36 NUM CD
# digits NOUN NNS
# ? PUNCT .
# What PRON WP
# is AUX VBZ
# the DET DT
# minimum ADJ JJ
# value NOUN NN
# of ADP IN
# 5x^2 NUM CD
# + NUM CD
# 5y^2 NUM CD
# - PUNCT HYPH
# 8xy NOUN NN
# when SCONJ WRB
# x PROPN NNP
# and CCONJ CC
# y PROPN NNP
# range VERB VBP
# over ADP IN
# all DET DT
# real ADJ JJ
# numbers NOUN NNS
# such ADJ JJ
# that SCONJ IN
# x-2y PROPN NNP
# + PUNCT NFP
# y-2x PROPN NNP
# = NOUN NN
# 40 NUM CD
# ? PUNCT .
# There PRON EX
# exists VERB VBZ
# a DET DT
# unique ADJ JJ
# increasing VERB VBG
# geometric ADJ JJ
# sequence NOUN NN
# of ADP IN
# five NUM CD
# 2 NUM CD
# - PUNCT HYPH
# digit NOUN NN
# positive ADJ JJ
# integers NOUN NNS
# . PUNCT .
# What PRON WP
# is AUX VBZ
# their PRON PRP$
# sum NOUN NN
# ? PUNCT .
# For ADP IN
# how SCONJ WRB
# many ADJ JJ
# positive ADJ JJ
# integers NOUN NNS
# m VERB VBP
# does AUX VBZ
# the DET DT
# equation NOUN NN
# [ PUNCT -LRB-
# x-1 X XX
# -2 NOUN NN
# = PROPN NNP
# m/100 PROPN NNP
# ] PUNCT -RRB-
# have VERB VBP
# 4 NUM CD
# distinct ADJ JJ
# solutions NOUN NNS
# ? PUNCT .
# Suppose VERB VB
# that SCONJ IN
# we PRON PRP
# roll VERB VBP
# four NUM CD
# 6 NUM CD
# - PUNCT HYPH
# sided ADJ JJ
# fair ADJ JJ
# dice NOUN NN
# with ADP IN
# faces NOUN NNS
# numbered VERB VBN
# 1 NUM CD
# to~6 NOUN NNS
# . PUNCT .
# Let VERB VB
# a DET DT
# / SYM SYM
# b X LS
# be AUX VB
# the DET DT
# probability NOUN NN
# that SCONJ IN
# the DET DT
# highest ADJ JJS
# roll NOUN NN
# is AUX VBZ
# a DET DT
# 5 NUM CD
# , PUNCT ,
# where SCONJ WRB
# a PRON DT
# and CCONJ CC
# b X LS
# are AUX VBP
# relatively ADV RB
# prime ADJ JJ
# positive ADJ JJ
# integers NOUN NNS
# . PUNCT .
# Find VERB VB
# a PRON DT
# + NUM CD
# b. NOUN NN
# The DET DT
# points NOUN NNS
# ( PUNCT -LRB-
# x PROPN NNP
# , PUNCT ,
# y PROPN NNP
# ) PUNCT -RRB-
# satisfying NOUN NN
# ( PUNCT -LRB-
# ( PUNCT -LRB-
# x PROPN NNP
# + CCONJ CC
# y PROPN NNP
# - PUNCT HYPH
# 10)^2 NUM CD
# + NUM CD
# ( PUNCT -LRB-
# x PROPN NNP
# - PUNCT HYPH
# y PROPN NNP
# - PUNCT HYPH
# 10)^2)((x NUM CD
# - PUNCT HYPH
# 8)^2 NUM CD
# + NUM CD
# ( PUNCT -LRB-
# y PROPN NNP
# - PUNCT HYPH
# 8)^2 PROPN NNP
# ) PUNCT -RRB-
# = X FW
# 0 NUM CD
# enclose VERB VB
# a DET DT
# convex ADJ JJ
# polygon NOUN NN
# . PUNCT .
# What PRON WP
# is AUX VBZ
# the DET DT
# area NOUN NN
# of ADP IN
# this DET DT
# convex ADJ JJ
# polygon NOUN NN
# ? PUNCT .
# Let VERB VB
# ABCD PROPN NNP
# be AUX VB
# a DET DT
# unit NOUN NN
# square NOUN NN
# . PUNCT .
# Let VERB VB
# P NOUN NN
# be AUX VB
# the DET DT
# point NOUN NN
# on ADP IN
# AB PROPN NNP
# such ADJ JJ
# that SCONJ IN
# AP PROPN NNP
# = SYM SYM
# 1/{20 NUM CD
# } PUNCT -RRB-
# and CCONJ CC
# let VERB VB
# Q PROPN NNP
# be AUX VB
# the DET DT
# point NOUN NN
# on ADP IN
# AD NOUN NN
# such ADJ JJ
# that SCONJ IN
# AQ PROPN NNP
# = PUNCT NFP
# 1/{24 NUM CD
# } PUNCT -RRB-
# . PUNCT .
# The DET DT
# lines NOUN NNS
# DP NOUN NN
# and CCONJ CC
# BQ PROPN NNP
# divide VERB VBP
# the DET DT
# square NOUN NN
# into ADP IN
# four NUM CD
# regions NOUN NNS
# . PUNCT .
# Find VERB VB
# the DET DT
# ratio NOUN NN
# between ADP IN
# the DET DT
# areas NOUN NNS
# of ADP IN
# the DET DT
# largest ADJ JJS
# region NOUN NN
# and CCONJ CC
# the DET DT
# smallest ADJ JJS
# region NOUN NN
# . PUNCT .
# A DET DT
# function NOUN NN
# f X XX
# : PUNCT :
# mathbb VERB VB
# N PROPN NNP
# to PART TO
# mathbb VERB VB
# N DET DT
# satisfies NOUN NNS
# the DET DT
# following VERB VBG
# two NUM CD
# conditions NOUN NNS
# for ADP IN
# all DET DT
# positive ADJ JJ
# integers NOUN NNS
# n X XX
# : PUNCT :
# f(f(f(n)))=8n-7 NOUN NN
# and CCONJ CC
# f(2n)=2f(n)+1 NOUN NN
# . PUNCT .
# Calculate VERB VB
# f(100 NOUN NN
# ) PUNCT -RRB-
# . PUNCT .

# %%
#looking at the dependency tags and the head of each token

for token in doc:
    print(token.i, token, token.dep_, token.head.i, token.head)
# Out:
# 0 Let ROOT 0 Let
# 1 k nsubj 6 be
# 2 , punct 1 k
# 3 l nmod 5 0
# 4 > nmod 5 0
# 5 0 conj 1 k
# 6 be compound 7 parameters
# 7 parameters dobj 0 Let
# 8 . punct 0 Let
# 9 The det 10 parabola
# 10 parabola nsubj 18 intersects
# 11 y nmod 15 2kx
# 12 = punct 11 y
# 13 kx^2 compound 15 2kx
# 14 - punct 15 2kx
# 15 2kx appos 10 parabola
# 16 + cc 10 parabola
# 17 l nsubj 18 intersects
# 18 intersects ROOT 18 intersects
# 19 the det 20 line
# 20 line dobj 18 intersects
# 21 y npadvmod 18 intersects
# 22 = ROOT 22 =
# 23 4 nummod 22 =
# 24 at prep 23 4
# 25 two nummod 26 points
# 26 points pobj 24 at
# 27 A dep 32 are
# 28 and cc 27 A
# 29 B. conj 27 A
# 30 These det 31 points
# 31 points nsubj 32 are
# 32 are ROOT 32 are
# 33 distance attr 32 are
# 34 6 nummod 33 distance
# 35 apart advmod 33 distance
# 36 . punct 32 are
# 37 What attr 38 is
# 38 is ROOT 38 is
# 39 the det 40 sum
# 40 sum nsubj 38 is
# 41 of prep 40 sum
# 42 the det 43 squares
# 43 squares pobj 41 of
# 44 of prep 43 squares
# 45 the det 46 distances
# 46 distances pobj 44 of
# 47 from prep 46 distances
# 48 A pobj 47 from
# 49 and cc 48 A
# 50 B conj 48 A
# 51 to prep 40 sum
# 52 the det 53 origin
# 53 origin pobj 51 to
# 54 ? punct 38 is
# 55 Each nsubj 65 is
# 56 of prep 55 Each
# 57 the det 61 numbers
# 58 three nummod 60 digits
# 59 - punct 60 digits
# 60 digits compound 61 numbers
# 61 numbers pobj 56 of
# 62 111 nummod 61 numbers
# 63 to prep 55 Each
# 64 999 pobj 63 to
# 65 is ROOT 65 is
# 66 coloured amod 67 blue
# 67 blue acomp 65 is
# 68 or cc 67 blue
# 69 yellow conj 67 blue
# 70 in prep 69 yellow
# 71 such predet 73 way
# 72 a det 73 way
# 73 way pobj 70 in
# 74 that advmod 87 is
# 75 the det 76 sum
# 76 sum nsubj 87 is
# 77 of prep 76 sum
# 78 any det 86 numbers
# 79 two nummod 86 numbers
# 80 ( punct 86 numbers
# 81 not neg 83 different
# 82 necessarily advmod 83 different
# 83 different amod 86 numbers
# 84 ) punct 86 numbers
# 85 yellow amod 86 numbers
# 86 numbers pobj 77 of
# 87 is acl 73 way
# 88 equal acomp 87 is
# 89 to prep 88 equal
# 90 a det 92 number
# 91 blue amod 92 number
# 92 number pobj 89 to
# 93 . punct 65 is
# 94 What attr 95 is
# 95 is ROOT 95 is
# 96 the det 99 number
# 97 maximum amod 99 number
# 98 possible amod 99 number
# 99 number nsubj 95 is
# 100 of prep 99 number
# 101 yellow amod 102 numbers
# 102 numbers pobj 100 of
# 103 there expl 105 be
# 104 can aux 105 be
# 105 be relcl 99 number
# 106 ? punct 95 is
# 107 Let ROOT 107 Let
# 108 the det 110 sparkle
# 109 ` punct 110 sparkle
# 110 sparkle poss 112 operation
# 111 ' case 110 sparkle
# 112 operation nsubj 117 consist
# 113 on prep 112 operation
# 114 positive amod 115 integer
# 115 integer pobj 113 on
# 116 n pobj 113 on
# 117 consist ccomp 107 Let
# 118 of prep 117 consist
# 119 calculating pcomp 118 of
# 120 the det 121 sum
# 121 sum dobj 119 calculating
# 122 of prep 121 sum
# 123 the det 124 digits
# 124 digits pobj 122 of
# 125 of prep 124 digits
# 126 n pobj 125 of
# 127 and cc 119 calculating
# 128 taking conj 119 calculating
# 129 its poss 130 factorial
# 130 factorial dobj 128 taking
# 131 , punct 134 sparkle
# 132 e.g. advmod 134 sparkle
# 133 the det 134 sparkle
# 134 sparkle nsubj 137 is
# 135 of prep 134 sparkle
# 136 13 pobj 135 of
# 137 is ccomp 107 Let
# 138 4 attr 137 is
# 139 ! punct 137 is
# 140 = ROOT 140 =
# 141 24 nummod 140 =
# 142 . punct 140 =
# 143 A det 144 robot
# 144 robot nsubj 145 starts
# 145 starts ccomp 164 replaces
# 146 with prep 145 starts
# 147 a det 149 integer
# 148 positive amod 149 integer
# 149 integer pobj 146 with
# 150 on prep 149 integer
# 151 a det 152 blackboard
# 152 blackboard pobj 150 on
# 153 , punct 164 replaces
# 154 then advmod 164 replaces
# 155 after prep 164 replaces
# 156 each det 157 second
# 157 second pobj 155 after
# 158 for prep 157 second
# 159 the det 160 rest
# 160 rest pobj 158 for
# 161 of prep 160 rest
# 162 eternity pobj 161 of
# 163 , punct 164 replaces
# 164 replaces ROOT 164 replaces
# 165 the det 166 number
# 166 number dobj 164 replaces
# 167 on prep 166 number
# 168 the det 169 board
# 169 board pobj 167 on
# 170 with prep 164 replaces
# 171 its poss 172 sparkle
# 172 sparkle pobj 170 with
# 173 . punct 164 replaces
# 174 For prep 195 be
# 175 some det 179 numbers
# 176 ` punct 179 numbers
# 177 special amod 179 numbers
# 178 ' punct 179 numbers
# 179 numbers pobj 174 For
# 180 , punct 195 be
# 181 if mark 183 're
# 182 they nsubj 183 're
# 183 're advcl 195 be
# 184 the det 186 number
# 185 first amod 186 number
# 186 number attr 183 're
# 187 , punct 195 be
# 188 then advmod 195 be
# 189 eventually advmod 195 be
# 190 every det 191 number
# 191 number nsubj 195 be
# 192 that nsubj 193 appears
# 193 appears relcl 191 number
# 194 will aux 195 be
# 195 be ROOT 195 be
# 196 less amod 198 6
# 197 than quantmod 198 6
# 198 6 attr 195 be
# 199 . punct 195 be
# 200 How advmod 201 many
# 201 many amod 204 numbers
# 202 such amod 204 numbers
# 203 special amod 204 numbers
# 204 numbers nsubj 205 are
# 205 are ROOT 205 are
# 206 there advmod 205 are
# 207 with prep 205 are
# 208 at advmod 210 36
# 209 most advmod 210 36
# 210 36 nummod 211 digits
# 211 digits pobj 207 with
# 212 ? punct 205 are
# 213 What attr 214 is
# 214 is ROOT 214 is
# 215 the det 217 value
# 216 minimum amod 217 value
# 217 value nsubj 214 is
# 218 of prep 217 value
# 219 5x^2 nummod 223 8xy
# 220 + nmod 219 5x^2
# 221 5y^2 compound 223 8xy
# 222 - punct 223 8xy
# 223 8xy pobj 218 of
# 224 when advmod 228 range
# 225 x nsubj 228 range
# 226 and cc 225 x
# 227 y conj 225 x
# 228 range advcl 214 is
# 229 over prep 228 range
# 230 all det 232 numbers
# 231 real amod 232 numbers
# 232 numbers pobj 229 over
# 233 such amod 234 that
# 234 that det 235 x-2y
# 235 x-2y appos 232 numbers
# 236 + cc 235 x-2y
# 237 y-2x conj 235 x-2y
# 238 = appos 235 x-2y
# 239 40 nummod 235 x-2y
# 240 ? punct 214 is
# 241 There expl 242 exists
# 242 exists ROOT 242 exists
# 243 a det 247 sequence
# 244 unique amod 247 sequence
# 245 increasing amod 247 sequence
# 246 geometric amod 247 sequence
# 247 sequence dobj 242 exists
# 248 of prep 247 sequence
# 249 five nummod 254 integers
# 250 2 nummod 252 digit
# 251 - punct 252 digit
# 252 digit nmod 254 integers
# 253 positive amod 254 integers
# 254 integers pobj 248 of
# 255 . punct 242 exists
# 256 What attr 257 is
# 257 is ROOT 257 is
# 258 their poss 259 sum
# 259 sum nsubj 257 is
# 260 ? punct 257 is
# 261 For prep 276 have
# 262 how advmod 263 many
# 263 many amod 265 integers
# 264 positive amod 265 integers
# 265 integers nsubj 266 m
# 266 m pcomp 261 For
# 267 does pobj 261 For
# 268 the det 269 equation
# 269 equation dobj 267 does
# 270 [ punct 261 For
# 271 x-1 pobj 261 For
# 272 -2 pobj 261 For
# 273 = pobj 261 For
# 274 m/100 pobj 261 For
# 275 ] punct 261 For
# 276 have ROOT 276 have
# 277 4 nummod 279 solutions
# 278 distinct amod 279 solutions
# 279 solutions dobj 276 have
# 280 ? punct 276 have
# 281 Suppose ROOT 281 Suppose
# 282 that mark 284 roll
# 283 we nsubj 284 roll
# 284 roll ccomp 281 Suppose
# 285 four nummod 290 dice
# 286 6 npadvmod 288 sided
# 287 - punct 288 sided
# 288 sided amod 290 dice
# 289 fair amod 290 dice
# 290 dice dobj 284 roll
# 291 with prep 290 dice
# 292 faces pobj 291 with
# 293 numbered ccomp 281 Suppose
# 294 1 nummod 295 to~6
# 295 to~6 dobj 293 numbered
# 296 . punct 281 Suppose
# 297 Let ROOT 297 Let
# 298 a det 300 b
# 299 / punct 300 b
# 300 b nsubj 301 be
# 301 be ccomp 297 Let
# 302 the det 303 probability
# 303 probability attr 301 be
# 304 that mark 308 is
# 305 the det 307 roll
# 306 highest amod 307 roll
# 307 roll nsubj 308 is
# 308 is acl 303 probability
# 309 a det 310 5
# 310 5 attr 308 is
# 311 , punct 310 5
# 312 where advmod 316 are
# 313 a nsubj 316 are
# 314 and cc 313 a
# 315 b conj 313 a
# 316 are relcl 310 5
# 317 relatively advmod 318 prime
# 318 prime amod 320 integers
# 319 positive amod 320 integers
# 320 integers attr 316 are
# 321 . punct 297 Let
# 322 Find ROOT 322 Find
# 323 a dobj 322 Find
# 324 + punct 322 Find
# 325 b. ROOT 325 b.
# 326 The det 327 points
# 327 points nsubj 358 enclose
# 328 ( punct 327 points
# 329 x appos 327 points
# 330 , punct 329 x
# 331 y appos 329 x
# 332 ) punct 333 satisfying
# 333 satisfying appos 327 points
# 334 ( punct 333 satisfying
# 335 ( punct 333 satisfying
# 336 x appos 327 points
# 337 + appos 327 points
# 338 y compound 340 10)^2
# 339 - punct 340 10)^2
# 340 10)^2 nummod 343 x
# 341 + punct 340 10)^2
# 342 ( punct 343 x
# 343 x appos 327 points
# 344 - punct 347 10)^2)((x
# 345 y compound 347 10)^2)((x
# 346 - punct 347 10)^2)((x
# 347 10)^2)((x appos 327 points
# 348 - punct 349 8)^2
# 349 8)^2 appos 327 points
# 350 + punct 327 points
# 351 ( punct 354 8)^2
# 352 y compound 354 8)^2
# 353 - punct 354 8)^2
# 354 8)^2 appos 327 points
# 355 ) punct 354 8)^2
# 356 = punct 327 points
# 357 0 punct 327 points
# 358 enclose ROOT 358 enclose
# 359 a det 361 polygon
# 360 convex amod 361 polygon
# 361 polygon dobj 358 enclose
# 362 . punct 358 enclose
# 363 What attr 364 is
# 364 is ROOT 364 is
# 365 the det 366 area
# 366 area nsubj 364 is
# 367 of prep 366 area
# 368 this det 370 polygon
# 369 convex amod 370 polygon
# 370 polygon pobj 367 of
# 371 ? punct 364 is
# 372 Let ROOT 372 Let
# 373 ABCD nsubj 374 be
# 374 be ccomp 372 Let
# 375 a det 376 unit
# 376 unit compound 377 square
# 377 square attr 374 be
# 378 . punct 372 Let
# 379 Let ROOT 379 Let
# 380 P nsubj 381 be
# 381 be ccomp 379 Let
# 382 the det 383 point
# 383 point attr 381 be
# 384 on prep 383 point
# 385 AB pobj 384 on
# 386 such amod 387 that
# 387 that det 388 AP
# 388 AP npadvmod 381 be
# 389 = npadvmod 381 be
# 390 1/{20 npadvmod 381 be
# 391 } punct 381 be
# 392 and cc 381 be
# 393 let conj 381 be
# 394 Q nsubj 395 be
# 395 be ccomp 393 let
# 396 the det 397 point
# 397 point attr 395 be
# 398 on prep 397 point
# 399 AD pobj 398 on
# 400 such amod 402 AQ
# 401 that det 402 AQ
# 402 AQ appos 399 AD
# 403 = punct 393 let
# 404 1/{24 dep 393 let
# 405 } punct 393 let
# 406 . punct 379 Let
# 407 The det 408 lines
# 408 lines nsubj 412 divide
# 409 DP appos 408 lines
# 410 and cc 409 DP
# 411 BQ conj 409 DP
# 412 divide ROOT 412 divide
# 413 the det 414 square
# 414 square dobj 412 divide
# 415 into prep 412 divide
# 416 four nummod 417 regions
# 417 regions pobj 415 into
# 418 . punct 412 divide
# 419 Find ROOT 419 Find
# 420 the det 421 ratio
# 421 ratio dobj 419 Find
# 422 between prep 421 ratio
# 423 the det 424 areas
# 424 areas pobj 422 between
# 425 of prep 424 areas
# 426 the det 428 region
# 427 largest amod 428 region
# 428 region pobj 425 of
# 429 and cc 428 region
# 430 the det 432 region
# 431 smallest amod 432 region
# 432 region conj 428 region
# 433 . punct 419 Find
# 434 A det 435 function
# 435 function ROOT 435 function
# 436 f appos 435 function
# 437 : punct 435 function
# 438 mathbb appos 435 function
# 439 N dobj 438 mathbb
# 440 to aux 441 mathbb
# 441 mathbb acl 435 function
# 442 N det 443 satisfies
# 443 satisfies dobj 441 mathbb
# 444 the det 447 conditions
# 445 following amod 447 conditions
# 446 two nummod 447 conditions
# 447 conditions dobj 441 mathbb
# 448 for prep 447 conditions
# 449 all det 451 integers
# 450 positive amod 451 integers
# 451 integers pobj 448 for
# 452 n prep 435 function
# 453 : punct 435 function
# 454 f(f(f(n)))=8n-7 appos 435 function
# 455 and cc 454 f(f(f(n)))=8n-7
# 456 f(2n)=2f(n)+1 conj 454 f(f(f(n)))=8n-7
# 457 . punct 435 function
# 458 Calculate compound 459 f(100
# 459 f(100 ROOT 459 f(100
# 460 ) punct 459 f(100
# 461 . punct 459 f(100

# %%
from spacy import displacy

# %%
#visualizing the universal dependencies for the first sentence

displacy.render(doc[:9], style="dep", options={"compact": True})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b4b5abb0692b440ea444e7457ccec3b7-0" class="displacy" width="1100" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Let</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">k,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">l</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">&gt;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">0</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">parameters.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b4b5abb0692b440ea444e7457ccec3b7-0-0" stroke-width="2px" d="M212,377.0 212,277.0 797.0,277.0 797.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b4b5abb0692b440ea444e7457ccec3b7-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,379.0 L208,371.0 216,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b4b5abb0692b440ea444e7457ccec3b7-0-1" stroke-width="2px" d="M362,377.0 362,327.0 641.0,327.0 641.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b4b5abb0692b440ea444e7457ccec3b7-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,379.0 L358,371.0 366,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b4b5abb0692b440ea444e7457ccec3b7-0-2" stroke-width="2px" d="M512,377.0 512,352.0 638.0,352.0 638.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b4b5abb0692b440ea444e7457ccec3b7-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,379.0 L508,371.0 516,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b4b5abb0692b440ea444e7457ccec3b7-0-3" stroke-width="2px" d="M212,377.0 212,302.0 644.0,302.0 644.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b4b5abb0692b440ea444e7457ccec3b7-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M644.0,379.0 L648.0,371.0 640.0,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b4b5abb0692b440ea444e7457ccec3b7-0-4" stroke-width="2px" d="M812,377.0 812,352.0 938.0,352.0 938.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b4b5abb0692b440ea444e7457ccec3b7-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M812,379.0 L808,371.0 816,371.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b4b5abb0692b440ea444e7457ccec3b7-0-5" stroke-width="2px" d="M62,377.0 62,252.0 950.0,252.0 950.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b4b5abb0692b440ea444e7457ccec3b7-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M950.0,379.0 L954.0,371.0 946.0,371.0" fill="currentColor"/>
# </g>
# </svg></span>
